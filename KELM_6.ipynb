# %%
import yfinance as yf
import pandas as pd

# Define the ticker symbol for Bank of India (BOI)
ticker = "BANKINDIA.NS"  # This is the ticker for Bank of India on the NSE

# Fetch historical data for the past 7 years
data = yf.download(ticker, start="2013-11-06", end="2020-06-12" )

# Display the first few rows of the data
print(data.head())

# Save the data to a CSV file if needed
data.to_csv('BOI_7_years_data.csv')

plt.figure(figsize= (12,6))
plt.plot(data.index, data['Close'], label = 'boi adj close', color = 'blue')
plt.title(" bank of india CLOSE P")
plt.xlabel("Date")
plt.ylabel("Close")
plt.legend()
plt.show()
# Out:
# [*********************100%***********************]  1 of 1 completed
#                   Open        High         Low       Close   Adj Close  \
# Date
# 2013-11-06  237.949997  239.750000  229.300003  230.699997  200.300415
# 2013-11-07  230.000000  234.899994  219.550003  220.750000  191.661530
# 2013-11-08  217.050003  224.750000  215.000000  219.899994  190.923538
# 2013-11-11  220.500000  226.699997  211.550003  216.050003  187.580872
# 2013-11-12  216.000000  221.350006  211.000000  212.300003  184.324997
#
#              Volume
# Date
# 2013-11-06  6535033
# 2013-11-07  6418681
# 2013-11-08  5181948
# 2013-11-11  5481785
# 2013-11-12  4489289

# %%
import yfinance as yf

# Define the ticker symbol for State Bank of India (SBI)
ticker = "SBIN.NS"  # SBI ticker symbol on NSE

# Fetch historical data (you can specify the date range)
data = yf.download(ticker, start="2013-11-06", end="2020-06-12") #yyyy-mm-dd
#data = data[0:500]
# Display the first few rows of the data
print(data.head())

# Save the data to a CSV file
data.to_csv('SBI_7_years_data.csv')
data.shape
# Out:
# [*********************100%***********************]  1 of 1 completed
#                   Open        High         Low       Close   Adj Close  \
# Date
# 2013-11-06  186.199997  188.535004  180.399994  180.955002  162.135391
# 2013-11-07  181.080002  182.800003  174.699997  175.259995  157.032684
# 2013-11-08  174.899994  176.800003  173.000000  174.429993  156.288971
# 2013-11-11  172.970001  175.294998  169.524994  170.434998  152.709473
# 2013-11-12  170.485001  171.699997  166.899994  167.294998  149.896042
#
#               Volume
# Date
# 2013-11-06  23159300
# 2013-11-07  31283760
# 2013-11-08  17637190
# 2013-11-11  18516020
# 2013-11-12  24334250
# (1620, 6)

# %%
import pandas as pd
import matplotlib.pyplot as plt


# !pip install pyreadr
import pyreadr

# Load the R data file using pyreadr
result = pyreadr.read_r('SymbolDataFileACC.RDS')

# Extract the dataframe from the result
data = result[None] # Assuming the data is stored without a key

#Convert index to datetime
data.index = pd.to_datetime(data.index)


# Plot the closing price
plt.figure(figsize=(16, 8))
# Access the 'ACC.Close' column instead of 'Close'
plt.plot(data.index, data['ACC.Close'], label=' ACC Close', color='blue')
plt.title("ACC Close Price")
plt.xlabel("Date")
plt.ylabel("Close")
plt.legend()
plt.show()
# Out:
# Requirement already satisfied: pyreadr in /usr/local/lib/python3.10/dist-packages (0.5.2)
# Requirement already satisfied: pandas>=1.2.0 in /usr/local/lib/python3.10/dist-packages (from pyreadr) (2.1.4)
# Requirement already satisfied: numpy<2,>=1.22.4 in /usr/local/lib/python3.10/dist-packages (from pandas>=1.2.0->pyreadr) (1.26.4)
# Requirement already satisfied: python-dateutil>=2.8.2 in /usr/local/lib/python3.10/dist-packages (from pandas>=1.2.0->pyreadr) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.10/dist-packages (from pandas>=1.2.0->pyreadr) (2024.1)
# Requirement already satisfied: tzdata>=2022.1 in /usr/local/lib/python3.10/dist-packages (from pandas>=1.2.0->pyreadr) (2024.1)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.10/dist-packages (from python-dateutil>=2.8.2->pandas>=1.2.0->pyreadr) (1.16.0)

# %%
print(data.head())
print(data.shape)
print(data.tail())
# Out:
#                                ACC.Open  ACC.High  ACC.Low  ACC.Close  \
# 1970-01-01 00:00:00.000000000       NaN       NaN      NaN        NaN
# 1970-01-01 00:00:00.000000001   1763.95   1763.95  1763.95    1763.95
# 1970-01-01 00:00:00.000000002   1763.90   1763.90  1758.65    1760.00
# 1970-01-01 00:00:00.000000003   1762.00   1763.80  1762.00    1763.80
# 1970-01-01 00:00:00.000000004   1763.45   1763.45  1760.00    1760.10
#
#                                ACC.Volume  ACC.OInt  LTSD20days
# 1970-01-01 00:00:00.000000000         NaN       NaN         NaN
# 1970-01-01 00:00:00.000000001       122.0       0.0         NaN
# 1970-01-01 00:00:00.000000002       718.0       0.0         NaN
# 1970-01-01 00:00:00.000000003       409.0       0.0         NaN
# 1970-01-01 00:00:00.000000004       867.0       0.0         NaN
# (484754, 7)
#                                ACC.Open  ACC.High  ACC.Low  ACC.Close  \
# 1970-01-01 00:00:00.000484749    1728.0   1732.80  1725.65     1727.6
# 1970-01-01 00:00:00.000484750    1727.7   1732.95  1726.00     1730.0
# 1970-01-01 00:00:00.000484751    1731.7   1731.70  1731.70     1731.7
# 1970-01-01 00:00:00.000484752    1731.7   1731.70  1731.70     1731.7
# 1970-01-01 00:00:00.000484753    1731.7   1731.70  1731.70     1731.7
#
#                                ACC.Volume  ACC.OInt  LTSD20days
# 1970-01-01 00:00:00.000484749     11845.0       0.0    0.002358
# 1970-01-01 00:00:00.000484750      5274.0       0.0    0.002358
# 1970-01-01 00:00:00.000484751         0.0       0.0    0.002358
# 1970-01-01 00:00:00.000484752         5.0       0.0    0.002358
# 1970-01-01 00:00:00.000484753         0.0       0.0    0.002358

# %%
plt.figure(figsize= (12,6))
plt.plot(data.index, data['Close'], label = 'sbi adj close', color = 'blue')
plt.title("SBI ADJ CLOSE P")
plt.xlabel("Date")
plt.ylabel("Adj Close")
plt.legend()
plt.show()
#it's s Close price plot not ADJ Close note that please all the plots are motivated to replicate the exact graph given in paper

# %%
import yfinance as yf
import pandas as pd

# Define the ticker symbol for Bank of India (BOI)
ticker = "YESBANK.NS"  # This is the ticker for Bank of India on the NSE

# Fetch historical data for the past 7 years
data = yf.download(ticker, start="2013-11-06", end="2020-06-12" )

# Display the first few rows of the data
print(data.head())

# Save the data to a CSV file if needed
data.to_csv('yesbank_7_years_data.csv')

plt.figure(figsize= (12,6))
plt.plot(data.index, data['Close'], label = 'yes bank close', color = 'blue')
plt.title(" yes bank CLOSE P")
plt.xlabel("Date")
plt.ylabel("Close")
plt.legend()
plt.show()
# Out:
# [*********************100%***********************]  1 of 1 completed
#                  Open       High        Low      Close  Adj Close    Volume
# Date
# 2013-11-06  74.940002  75.480003  72.820000  73.680000  68.182671  31461630
# 2013-11-07  74.199997  74.989998  71.910004  72.150002  66.766823  34542345
# 2013-11-08  72.529999  73.080002  70.480003  70.849998  65.563820  40878305
# 2013-11-11  70.250000  70.580002  66.349998  66.690002  61.714203  47216800
# 2013-11-12  66.970001  68.500000  65.160004  65.790001  60.881359  34123545

# %%
import pandas as pd
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import MinMaxScaler
import tensorflow as tf
from tensorflow.keras import layers, models
import numpy as np
import matplotlib.pyplot as plt
from sklearn.metrics import r2_score
from sklearn.metrics import mean_absolute_error, mean_squared_error

# Step 1: Data Preprocessing
data = pd.read_csv('yesbank_7_years_data.csv')
X = data[['Open', 'High', 'Low', 'Close']]
y = data['Close']

scaler = MinMaxScaler()
X_scaled = scaler.fit_transform(X)
X_train, X_test, y_train, y_test = train_test_split(X_scaled, y, test_size=0.3, random_state=42)

# %%
print(y_train)
# Out:
# 1252    166.199997
# 155     110.050003
# 881     295.239990
# 1225    181.300003
# 490     156.750000
#            ...
# 1130    337.649994
# 1294    176.449997
# 860     319.679993
# 1459     41.049999
# 1126    342.950012
# Name: Close, Length: 1134, dtype: float64

# %%
import pandas as pd


df = pd.DataFrame(data)
df.isna().sum()
print(df.shape)
df.dropna(inplace = True)
print(df.head())
print(df.shape)
print(df.tail())
df
# Out:
# (484754, 7)
#                                ACC.Open  ACC.High  ACC.Low  ACC.Close  \
# 1970-01-01 00:00:00.000007504   1738.70   1738.70   1738.7    1738.70
# 1970-01-01 00:00:00.000007505   1728.00   1728.00   1728.0    1728.00
# 1970-01-01 00:00:00.000007506   1729.80   1736.60   1729.8    1730.00
# 1970-01-01 00:00:00.000007507   1729.80   1733.95   1728.4    1731.00
# 1970-01-01 00:00:00.000007508   1730.75   1732.30   1728.8    1728.95
#
#                                ACC.Volume  ACC.OInt  LTSD20days
# 1970-01-01 00:00:00.000007504         1.0       0.0    0.000721
# 1970-01-01 00:00:00.000007505        54.0       0.0    0.000721
# 1970-01-01 00:00:00.000007506      1288.0       0.0    0.000721
# 1970-01-01 00:00:00.000007507      1346.0       0.0    0.000721
# 1970-01-01 00:00:00.000007508       781.0       0.0    0.000721
# (477250, 7)
#                                ACC.Open  ACC.High  ACC.Low  ACC.Close  \
# 1970-01-01 00:00:00.000484749    1728.0   1732.80  1725.65     1727.6
# 1970-01-01 00:00:00.000484750    1727.7   1732.95  1726.00     1730.0
# 1970-01-01 00:00:00.000484751    1731.7   1731.70  1731.70     1731.7
# 1970-01-01 00:00:00.000484752    1731.7   1731.70  1731.70     1731.7
# 1970-01-01 00:00:00.000484753    1731.7   1731.70  1731.70     1731.7
#
#                                ACC.Volume  ACC.OInt  LTSD20days
# 1970-01-01 00:00:00.000484749     11845.0       0.0    0.002358
# 1970-01-01 00:00:00.000484750      5274.0       0.0    0.002358
# 1970-01-01 00:00:00.000484751         0.0       0.0    0.002358
# 1970-01-01 00:00:00.000484752         5.0       0.0    0.002358
# 1970-01-01 00:00:00.000484753         0.0       0.0    0.002358
#                                ACC.Open  ACC.High  ACC.Low  ACC.Close  \
# 1970-01-01 00:00:00.000007504   1738.70   1738.70  1738.70    1738.70
# 1970-01-01 00:00:00.000007505   1728.00   1728.00  1728.00    1728.00
# 1970-01-01 00:00:00.000007506   1729.80   1736.60  1729.80    1730.00
# 1970-01-01 00:00:00.000007507   1729.80   1733.95  1728.40    1731.00
# 1970-01-01 00:00:00.000007508   1730.75   1732.30  1728.80    1728.95
# ...                                 ...       ...      ...        ...
# 1970-01-01 00:00:00.000484749   1728.00   1732.80  1725.65    1727.60
# 1970-01-01 00:00:00.000484750   1727.70   1732.95  1726.00    1730.00
# 1970-01-01 00:00:00.000484751   1731.70   1731.70  1731.70    1731.70
# 1970-01-01 00:00:00.000484752   1731.70   1731.70  1731.70    1731.70
# 1970-01-01 00:00:00.000484753   1731.70   1731.70  1731.70    1731.70
#
#                                ACC.Volume  ACC.OInt  LTSD20days
# 1970-01-01 00:00:00.000007504         1.0       0.0    0.000721
# 1970-01-01 00:00:00.000007505        54.0       0.0    0.000721
# 1970-01-01 00:00:00.000007506      1288.0       0.0    0.000721
# 1970-01-01 00:00:00.000007507      1346.0       0.0    0.000721
# 1970-01-01 00:00:00.000007508       781.0       0.0    0.000721
# ...                                   ...       ...         ...
# 1970-01-01 00:00:00.000484749     11845.0       0.0    0.002358
# 1970-01-01 00:00:00.000484750      5274.0       0.0    0.002358
# 1970-01-01 00:00:00.000484751         0.0       0.0    0.002358
# 1970-01-01 00:00:00.000484752         5.0       0.0    0.002358
# 1970-01-01 00:00:00.000484753         0.0       0.0    0.002358
#
# [477250 rows x 7 columns]

# %%
import pandas as pd
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import MinMaxScaler
import tensorflow as tf
from tensorflow.keras import layers, models
import numpy as np
import matplotlib.pyplot as plt
from sklearn.metrics import r2_score
from sklearn.metrics import mean_absolute_error, mean_squared_error

# Step 1: Data Preprocessing
data = df
#X = data[['Open', 'High', 'Low', 'Close']]
X = data[['ACC.Open', 'ACC.High', 'ACC.Low', 'ACC.Close']]
y = data['ACC.Close']

scaler = MinMaxScaler()
X_scaled = scaler.fit_transform(X)
X_train, X_test, y_train, y_test = train_test_split(X_scaled, y, test_size=0.3, random_state=42)

# Step 2: Stacked Autoencoder (SAE)
input_dim = X_train.shape[1]
encoding_dim = 32

input_layer = layers.Input(shape=(input_dim,))
encoded = layers.Dense(encoding_dim, activation='relu')(input_layer)
decoded = layers.Dense(input_dim, activation='sigmoid')(encoded)

autoencoder = models.Model(input_layer, decoded)
autoencoder.compile(optimizer='adam', loss='mse')
autoencoder.fit(X_train, X_train, epochs=1, batch_size=32, shuffle=True, validation_data=(X_test, X_test))

encoder = models.Model(input_layer, encoded)
X_train_encoded = encoder.predict(X_train)
X_test_encoded = encoder.predict(X_test)

# Step 3: Kernel Extreme Learning Machine (KELM)
def polynomial_kernel(X, Y, degree=3, coef0=1):
    return (np.dot(X, Y.T) + coef0) ** degree

def rbf_kernel(X, Y, gamma=0.1):
    if gamma is None:
        gamma = 1.0 / X.shape[1]
    return np.exp(-gamma * np.linalg.norm(X[:, np.newaxis] - Y, axis=2) ** 2)

def sigmoid_kernel(X, Y, coef0=1, gamma=0.1):
    return np.tanh(gamma * np.dot(X, Y.T) + coef0)

class KELM:
    def __init__(self, kernel='rbf', C=1.0, degree=3, gamma=None, coef0=1):
        self.C = C
        self.degree = degree
        self.gamma = gamma
        self.coef0 = coef0
        self.kernel = kernel
        self.alpha_ = None

    def _compute_kernel(self, X, Y):
        if self.kernel == 'polynomial':
            return polynomial_kernel(X, Y, self.degree, self.coef0)
        elif self.kernel == 'rbf':
            return rbf_kernel(X, Y, self.gamma)
        elif self.kernel == 'sigmoid':
            return sigmoid_kernel(X, Y, self.coef0, self.gamma)
        else:
            raise ValueError("Unsupported kernel type")

    def fit(self, X, y):
        K = self._compute_kernel(X, X)
        N = K.shape[0]
        I = np.identity(N)
        self.alpha_ = np.linalg.inv(I / self.C + K).dot(y)
        self.X_train_ = X

    def predict(self, X):
        K_test = self._compute_kernel(X, self.X_train_)
        return K_test.dot(self.alpha_)

kelm = KELM(kernel='polynomial', C=1.0, gamma=0.1)
kelm.fit(X_train_encoded, y_train)
y_pred = kelm.predict(X_test_encoded)

# Step 4: Evaluation
def mean_absolute_percentage_error(y_true, y_pred):
    return np.mean(np.abs((y_true - y_pred) / y_true)) * 100

mape = mean_absolute_percentage_error(y_test, y_pred)
mae = mean_absolute_error(y_test, y_pred)
rmse = np.sqrt(mean_squared_error(y_test, y_pred))
r_squared = r2_score(y_test, y_pred)


print(f"MAPE: {mape:.2f}%")
print(f"MAE: {mae:.4f}")
print(f"RMSE: {rmse:.4f}")
print(f"R-squared: {r_squared:.4f}")

# Step 5: Visualization
plt.figure(figsize=(14, 7))
plt.plot(y_test.values, label='Actual Prices', color='blue')
plt.plot(y_pred, label='Predicted Prices', color='red')
plt.title('Actual vs Predicted Stock Prices')
plt.xlabel('Time')
plt.ylabel('Stock Price')
plt.legend()
plt.show()
# Out:
# 10440/10440 ━━━━━━━━━━━━━━━━━━━━ 29s 3ms/step - loss: 0.0044 - val_loss: 1.4831e-04
# 10440/10440 ━━━━━━━━━━━━━━━━━━━━ 17s 2ms/step
# 4475/4475 ━━━━━━━━━━━━━━━━━━━━ 7s 2ms/step

# %%
# Step 4: Evaluation
def mean_absolute_percentage_error(y_true, y_pred):
    return np.mean(np.abs((y_true - y_pred) / y_true)) * 100

mape = mean_absolute_percentage_error(y_test, y_pred)
mae = mean_absolute_error(y_test, y_pred)
rmse = np.sqrt(mean_squared_error(y_test, y_pred))
r_squared = r2_score(y_test, y_pred)


print(f"MAPE: {mape:.2f}%")
print(f"MAE: {mae:.4f}")
print(f"RMSE: {rmse:.4f}")
print(f"R-squared: {r_squared:.4f}")

# Step 5: Visualization
plt.figure(figsize=(14, 7))
plt.plot(y_test.values, label='Actual Prices', color='blue')
plt.plot(y_pred, label='Predicted Prices', color='red')
plt.title('Actual vs Predicted Stock Prices')
plt.xlabel('Time')
plt.ylabel('Stock Price')
plt.legend()
plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-1a0a909880b4> in <cell line: 5>()
#       3     return np.mean(np.abs((y_true - y_pred) / y_true)) * 100
#       4
# ----> 5 mape = mean_absolute_percentage_error(y_test, y_pred)
#       6 mae = mean_absolute_error(y_test, y_pred)
#       7 rmse = np.sqrt(mean_squared_error(y_test, y_pred))
#
# NameError: name 'y_test' is not defined

# %%
#SBI table
'''MAPE: 0.10%
   MAE: 0.2232
   RMSE: 0.3918
   R-squared: 0.9999'''
# Out:
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step

# %%
#boi
''' MAPE: 0.29%
MAE: 0.3342
RMSE: 0.4401
R-squared: 1.0000'''
# Out:
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step

# %%
import matplotlib.pyplot as plt
# Get predictions for the entire dataset
X_scaled_all = scaler.transform(X)
X_encoded_all = encoder.predict(X_scaled_all)
y_pred_all = kelm.predict(X_encoded_all)

# Plot the actual and predicted values for the entire dataset
plt.figure(figsize=(14, 7))
plt.plot(y.values, label='Actual Prices', color='blue')
plt.plot(y_pred_all, label='Predicted Prices', color='red')
plt.title('Actual vs Predicted Stock Prices (Complete Dataset)')
plt.xlabel('Time')
plt.ylabel('Stock Price')
plt.legend()
plt.show()
#here the value of MAPE, MAE, RMSE are not matching we must look for some rectification but the strange thing is
#model is fitting well in test data and by that the model is mimicking well !!
#YES bank

''' MAPE: 0.40%
MAE: 0.3974
RMSE: 0.6205
R-squared: 1.0000 '''
# Out:
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 0s 994us/step
# ' MAPE: 0.40%\nMAE: 0.3974\nRMSE: 0.6205\nR-squared: 1.0000 '

# %% [markdown]
# # New Section

# %%
import pandas as pd
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import MinMaxScaler
import tensorflow as tf
from tensorflow.keras import layers, models
import numpy as np
import matplotlib.pyplot as plt
from sklearn.metrics import r2_score
from sklearn.metrics import mean_absolute_error, mean_squared_error


# Step 1: Data Preprocessing
data = pd.read_csv('SBI_7_years_data.csv')
X = data[['Open', 'High', 'Low', 'Close']]
y = data['Close']

scaler = MinMaxScaler()
X_scaled = scaler.fit_transform(X)
X_train, X_test, y_train, y_test = train_test_split(X_scaled, y, test_size=0.3, random_state=42)

# Step 2: Stacked Autoencoder (SAE)
input_dim = X_train.shape[1]
encoding_dim = 32

input_layer = layers.Input(shape=(input_dim,))
encoded = layers.Dense(encoding_dim, activation='relu')(input_layer)
decoded = layers.Dense(input_dim, activation='sigmoid')(encoded)

autoencoder = models.Model(input_layer, decoded)
autoencoder.compile(optimizer='adam', loss='mse')
autoencoder.fit(X_train, X_train, epochs=50, batch_size=32, shuffle=True, validation_data=(X_test, X_test))

encoder = models.Model(input_layer, encoded)
X_train_encoded = encoder.predict(X_train)
X_test_encoded = encoder.predict(X_test)

# Step 3: Kernel Extreme Learning Machine (KELM)
def polynomial_kernel(X, Y, degree=3, coef0=1):
    return (np.dot(X, Y.T) + coef0) ** degree

def rbf_kernel(X, Y, gamma=0.1):
    if gamma is None:
        gamma = 1.0 / X.shape[1]
    return np.exp(-gamma * np.linalg.norm(X[:, np.newaxis] - Y, axis=2) ** 2)

def sigmoid_kernel(X, Y, coef0=1, gamma=0.1):
    return np.tanh(gamma * np.dot(X, Y.T) + coef0)

class KELM:
    def __init__(self, kernel='rbf', C=1.0, degree=3, gamma=None, coef0=1):
        self.C = C
        self.degree = degree
        self.gamma = gamma
        self.coef0 = coef0
        self.kernel = kernel
        self.alpha_ = None

    def _compute_kernel(self, X, Y):
        if self.kernel == 'polynomial':
            return polynomial_kernel(X, Y, self.degree, self.coef0)
        elif self.kernel == 'rbf':
            return rbf_kernel(X, Y, self.gamma)
        elif self.kernel == 'sigmoid':
            return sigmoid_kernel(X, Y, self.coef0, self.gamma)
        else:
            raise ValueError("Unsupported kernel type")

    def fit(self, X, y):
        K = self._compute_kernel(X, X)
        N = K.shape[0]
        I = np.identity(N)
        self.alpha_ = np.linalg.inv(I / self.C + K).dot(y)
        self.X_train_ = X

    def predict(self, X):
        K_test = self._compute_kernel(X, self.X_train_)
        return K_test.dot(self.alpha_)

kelm = KELM(kernel='polynomial', C=1.0, gamma=0.1)


#print(kelm.X_train_)
print(kelm.C)
print(kelm.alpha_)
print(kelm.degree)
print(kelm.gamma)
print(kelm.coef0)
print(kelm.kernel)
MYKELMFIT = kelm.fit(X_train_encoded, y_train)
print('****'  )
print(kelm.X_train_)
print(kelm.C)
print(kelm.alpha_)
print(kelm.degree)
print(kelm.gamma)
print(kelm.coef0)
print(kelm.kernel)

# %%
print(kelm.X_train_.shape)
print(kelm.C)
print(kelm.alpha_.shape)
print(kelm.degree)
print(kelm.gamma)
print(kelm.coef0)
print(kelm.kernel)
a = kelm.alpha_
b= []
for i in range(a.shape[0]) :
  b.append(a[i])
print(b)
